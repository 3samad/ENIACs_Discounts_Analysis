# %% [markdown]
# # Summary
#
# The products dataframe was corrupted and needs cleaning. \
# We have decided the following:
# 1. price column had corrupted data with the following issues that were fixed:
#     - Some values had two decimal points. The first point got removed.
#     - The values with two decimal points were also 100x the correct value. We divided by 100.
# 2. promo_price is unnecessary and will be removed. We will determine discounted price based on orderlines.unit_price
# 3. We will add the brands to products dataframe as separating it is redundant for our purposes.

# %% [markdown]
# ### Imports

# %%
import pandas as pd

# products.csv ##################################
url = "https://drive.google.com/file/d/1khUA0GrhC4cdAgg7-Zn3RX2vI9dcxWMa/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
products = pd.read_csv(path)

# brands.csv ####################################
url = "https://drive.google.com/file/d/1yBGBdJlpIjel_9Yp5HJWO_mBLPv39fx5/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
brands = pd.read_csv(path)

# products_clean.csv ####################################
url = "https://drive.google.com/file/d/1RfVACMhoaTl3j8gV9ZdyVWZV_TlfZgx_/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
products_cleaned = pd.read_csv(path)

# %% [markdown]
# # Price
#
# It is clear that the price column has been corrupted and carries values with two decimal points and an extra three digits. \
# It is unclear *why* however the pattern seems to be predictable. We will clean and reassess.

# %% [markdown]
# ### First we apply all our standard cleaning

# %%
products = products.drop_duplicates(subset = "sku") # Drop duplicates
products = products.loc[~products['price'].isna()] # Drop rows with missing prices

# %% [markdown]
# ### Then we have a look at the sample

# %%
products.sample(20)
# Out:
#              sku                                               name  \
# 1969     PAC0779  Samsung SSD 850 expansion kit PRO 500GB + OWC ...
# 13306    OTT0148      OtterBox iPhone Case Symmetry 7/8 Clear Clear
# 2289     TRA0013  Transcend JetDrive Lite 350 64GB Macbook Pro R...
# 17243    AP20292             Like new - Apple 38mm Sport Black Belt
# 2399     DEV0011                        Devolo Wifi Repeater 24 GHz
# 10694    SYN0128               Synology DS416 NAS server Mac and PC
# 2857     STA0023  Startech Adapter Kit Mini DisplayPort / VGA / ...
# 13043    BNQ0048   BL2420U BenQ Monitor 236 "4K 100% sRGB pivotable
# 14769    QNA0198                  QNAP TS-831X Server Nas | 8GB RAM
# 2579     APP1004  Apple MacBook Pro Retina 15 "i7 22GHz | 16GB R...
# 14265    APP1912  Apple MacBook Pro 15 "Core i7 Touch Bar 29GHz ...
# 18136  APP1961-A            Like new - Apple iPhone SE 128GB Silver
# 15892    PAC1996  Synology DS1517 + | 2GB RAM | 10TB (5x2TB) WD Red
# 12973  HGD0009-A  Open - Henge Docks Docking Station MacBook Air...
# 880      PAR0015   Parrot Flower Power Plants Wireless Sensor Green
# 1215     GRT0335           Griffin Survivor Case iPhone 6 Plus Blue
# 17060    AP20215  Like new - magnetic charging cable for Apple W...
# 1983     SHE0024         SwitchEasy iPhone 6 Plus Case Airmask Gray
# 13323    APP1755     Apple iPad Mini 4 Wi-Fi + Cellular 32GB Silver
# 10697    PAC1167        Synology DS416 Pack | Seagate 12TB IronWolf
#
#                                                     desc    price promo_price  \
# 1969   500GB SSD expansion kit + Adapter Mount Pro fo...   285.98   2.405.843
# 13306  resistant and anti thin sheath bevelled edges ...    34.99       22.99
# 2289   MLC memory card 64GB for Macbooks Retina 15 in...       46     429.901
# 17243  Durable and flexible strap sports with clip cl...       59     389.995
# 2399                    Amplifier Wi-Fi N 24 GHz Devolo.  399.905     329.846
# 10694  Synology NAS server 4 bays and DLNA Media Center.   385.99   3.849.893
# 2857   Mini DisplayPort adapter kit / HDMI / VGA / US...    86.99       69.99
# 13043  Monitor for design professionals 4K resolution...   399.99     398.989
# 14769  8-bay NAS server for business environment with...   930.49   9.299.903
# 2579   New MacBook Pro 15-inch Retina screen Core i7 ...     2969  27.610.046
# 14265  New MacBook Pro 15-inch Core i7 Touch Bar 29Gh...     4879  46.415.842
# 18136  iPhone SE open but as new with 4 inch 128 GB f...      529   4.676.686
# 15892  NAS server with 2GB of RAM and 10TB for Mac an...  1300.86  12.299.626
# 12973           Dock MacBook Air 13-inch multi-function.    79.99      75.988
# 880      Wi-Fi sensor for remote control and plant care.    59.95     398.889
# 1215   Funda iPhone 6 ultra resistant for extreme con...    44.99     299.899
# 17060  Magnetic charging cable for Apple Watch recond...       45     349.932
# 1983   Protective cover with 360 degrees for iPhone 6...    29.99     249.865
# 13323           Apple iPad Mini 4 Wi-Fi + Cellular 32GB.      549     536.802
# 10697  Synology DS416 pack of 12TB (4x3TB) Seagate Ha...   945.95   8.153.682
#
#        in_stock      type
# 1969          1      1433
# 13306         0  11865403
# 2289          0  57445397
# 17243         0      2449
# 2399          1      1334
# 10694         0  12175397
# 2857          0      1325
# 13043         0      1296
# 14769         0  12175397
# 2579          0      1282
# 14265         0      2158
# 18136         0  51601716
# 15892         0  12175397
# 12973         0      1298
# 880           0  11905404
# 1215          0  11865403
# 17060         0      1298
# 1983          0  11865403
# 13323         0  24861714
# 10697         0  12175397

# %% [markdown]
# ### Then we apply our methods to normalize the data

# %%
# Where 'price' contains double dots
double_dot_entries = products.price.astype(str).str.contains("\d+\.\d+\.\d+")

# Remove decimals, convert to int, divide by 100000, and round to two decimal places
products.loc[double_dot_entries, 'price'] = (products.loc[double_dot_entries, 'price'].str.replace('.', '')  # remove decimals
                                                                                                        .astype(int)  # convert to integer
                                                                                                        / 100000).round(2)  # divide by 100000 and round to two decimal places
products.loc['price'] = pd.to_numeric(products['price'])
# Out:
# <ipython-input-66-073b0a22a024>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   products.loc[double_dot_entries, 'price'] = (products.loc[double_dot_entries, 'price'].str.replace('.', '')  # remove decimals

# %%
# Now we check our work
products.sample(20)
# Out:
#              sku                                               name  \
# 12886    PAC2043  Synology DS216 + II | Seagate 4TB IronWolf for...
# 12679    MOP0084  Mophie Power Reserve 2600 mAh battery 1X White...
# 17679  IHE0020-A   Open - iHealth Box 50 Reagent Strips glucímetros
# 15736    APP2050       Open - Apple iPhone 7128 GB Black - Like New
# 2924     KEN0220  Kensingnton Minisaver security Cable for Mac a...
# 1954     PAC0717  Samsung SSD 850 expansion kit EVO 1TB + 8GB RA...
# 359      MUV0045  Muvit iPhone in September matte Screen Savers ...
# 11706  DRO0009-A  (Open) Data Robotics Drobo 5D USB 3.0 Thunderb...
# 12996  SPH0008-A      (Open) SPRK Sphero Robotic Transparent Sphere
# 18128    NTE0131   NewerTech NuGuard KX X-treme iPhone Case Red 8/7
# 2110     APP0958  Apple MacBook Pro Retina 13 "i5 27 Ghz | 8GB R...
# 2529     FCM0020             FCM Mac Memory 1GB 667MHz DDR2 SO-DIMM
# 11451    DLK0134         D-Link mydlink DCH-Z120 Home Motion Sensor
# 13100    GTE0081  G-Technology G-RAID Thunderbolt 20TB Extraible...
# 15784    SNN0054  Sonnet Twin 10G SFP + 10G SFP + adapter chassi...
# 16335    APP2269  Apple MacBook Pro 13 "Core i5 Touch Bar 33GHz ...
# 14476    LAC0222  96TB 12big LaCie Hard Disk Thunderbolt RAID 3 ...
# 11154    PAC1319       Pack QNAP TS-253A | 4GB RAM | WD 8TB Network
# 13174    PAC1509  Pack QNAP TS-251A NAS Server | 2GB RAM | WD 16...
# 1307     PAR0027      Parrot Central Cross Rolling Spider MiniDrone
#
#                                                     desc    price  in_stock  \
# 12886  Synology DS216 + II with 8GB of RAM and 20TB (...   170.79       0.0
# 12679  Laptop Battery 2600mAh (18A) with LED and micr...    39.95       0.0
# 17679  Blood glucose test strips in the iHealth glucí...    19.95       0.0
# 15736     Apple iPhone 7 Free 128 GB Black (MN922QL / A)      879       0.0
# 2924               Cable ultralight Mac and PC security.    69.99       0.0
# 1954   Upgrade kit 1TB SSD + Datadoubler Mac Mini 200...   605.96       1.0
# 359    Set 2 screen protectors for iPhone matte finis...     8.99       0.0
# 11706         Mac and PC RAID 5-bay Thunderbolt USB 3.0.      749       0.0
# 12996                    programmable robot for IOS SPRK   149.95       0.0
# 18128  Protective cover for massive drops NuGuard KX ...    60.99       0.0
# 2110   New MacBook Pro 13-inch Retina screen i5 128GB...     1449       0.0
# 2529   1GB RAM Mac mini and iMac (2006/07) MacBook Pr...    10.99       0.0
# 11451  Wireless motion sensor security system my D-Li...    49.99       0.0
# 13100  20TB RAID disk with 2 bays and removable disks...  1358.99       0.0
# 15784  Chassis fiber optic adapter Thunderbolt 3 for ...   785.29       0.0
# 16335  New MacBook Pro 13 inch Touch Bar 33 GHz Core ...     2869       0.0
# 14476  12 Hard Drive 96TB RAID 5 bays with two ports ...     8199       0.0
# 11154  QNAP pack with 4GB of RAM memory + 8TB (2x4TB)...   727.99       1.0
# 13174  NAS with 2GB of RAM and two hard disks 8TB (2x...  1067.69       0.0
# 1307             Rolling MiniDrone Central Cross Spider.     5.99       0.0
#
#            type
# 12886  12175397
# 12679      1515
# 17679      1298
# 15736      1716
# 2924       1325
# 1954       1433
# 359    13555403
# 11706      1298
# 12996      1298
# 18128  11865403
# 2110       1282
# 2529       1364
# 11451  11905404
# 13100  11935397
# 15784  12995397
# 16335  1,02E+12
# 14476  11935397
# 11154  12175397
# 13174  12175397
# 1307   11905404

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10535 entries, 0 to price
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sku       10534 non-null  object
#  1   name      10534 non-null  object
#  2   desc      10527 non-null  object
#  3   price     10534 non-null  object
#  4   in_stock  10534 non-null  float64
#  5   type      10484 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 834.2+ KB

# %% [markdown]
# ### Analysis
#
# We can see by combing the samples that we have successfully fixed the issue and the prices are now usable.
# As this makes up a large portion of our overall data, this was almost definitely worth the effort.

# %% [markdown]
# # Promo_price
#
# The promo_price column has been corrupted. While it is possible to fix it, we can take more \
# concrete payment data from orderlines.unit_price so we will remove this column entirely.

# %%
products.drop('promo_price', axis=1, inplace=True)

# %% [markdown]
# # Brands
#
# We will add the brands columns to the products dataframes to make exploration easier.

# %%
# merge the products and brands dataframes
merged_df = pd.merge(products, brands, left_on=products['sku'].str[:3], right_on=brands['short'], how='left')

# drop the redundant short column as it isn't necessary. The three letters are already supplied in the sku column
merged_df.drop(['key_0', 'short'], axis=1, inplace=True)

# rename the 'long' column to brand
merged_df.rename(columns={'long': 'brand'}, inplace=True)

# %% [markdown]
# # Download

# %%
 #from google.colab import files

 #products.to_csv("Cleaned_products.csv", index=False)
 #files.download("Cleaned_products.csv")

# %% [markdown]
# # Testing Sample
#
# Check that the data makes sense.

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10535 entries, 0 to price
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sku       10534 non-null  object
#  1   name      10534 non-null  object
#  2   desc      10527 non-null  object
#  3   price     10534 non-null  object
#  4   in_stock  10534 non-null  float64
#  5   type      10484 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 576.1+ KB

# %%
products_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10534 entries, 0 to 10533
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sku       10534 non-null  object
#  1   name      10534 non-null  object
#  2   desc      10527 non-null  object
#  3   price     10534 non-null  float64
#  4   in_stock  10534 non-null  int64
#  5   type      10484 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 493.9+ KB

# %%
products.sample(50)
# Out:
#              sku                                               name  \
# 1869     PAC0623  Samsung SSD 850 expansion kit EVO 500GB + OWC ...
# 2697     IFX0031  iFixit PATA adapter 127mm optical bay Macbook ...
# 13063    GTE0137  G-Technology G-DRIVE Mobile Hard Drive 1TB USB...
# 13793    APP1838  Apple MacBook Pro 13 "Core i5 with Touch Bar 3...
# 12325  AII0037-A  (Open) Aiino housing Retina MacBook Pro 15 "Tr...
# 2961     LIF0076  Lifeproof LifeActiv Bracelet + adapter QuickMount
# 7825     PAC1626  Apple iMac 27 "Core i7 Retina 5K 4GHz | 8GB RA...
# 2933     MUV0163  Muvit Bracelet Universal Fino 4-47 "Lima + Spo...
# 2025     PHI0052              Philips Hue Bloom separate light lamp
# 17416    AP20305             Like new - Apple iPhone 32GB Rose Gold
# 16905    SNN0062  Sonnet eGFX Breakaway Box 550W PCIe Thunderbol...
# 12528    MOO0008                Now Moov Red Coach Activity Monitor
# 12250    IFX0045      iFixit 64 Bit Driver Kit 64 parts Screwdriver
# 13615    APP1798  Braided Strap 38mm Nailon Apple Yellow / Light...
# 18684  WDT0349-A  Open - WD My Passport 2TB External Hard Drive ...
# 1218     GRT0340                 Griffin Reveal Case iPhone 6 White
# 13235    WDT0342                  WD Red Pro 4TB 35 "Sata 3 7200RPM
# 15940  TUC0304-A  Open - Tucano Nido Hard-Shell Case MacBook Pro...
# 924      DLK0060           D-Link DGS-1024D Gigabit Switch 24 Ports
# 1795     BEZ0179  Be.ez LArobe MacBook Pro Retina sleeve ONE 13 ...
# 2041     BEL0175  Belkin WeMO Led Lighting LED Bulbs Sept. 2 + W...
# 6354     PAC1068  Apple iMac 27 "Core i5 3.3GHz Retina 5K | 16GB...
# 18807    LIF0131        LifeProof Fre Waterproof Case iPhone X Lila
# 16885    PAC2159  Apple Mac Pro 12-core 27GHz | 64GB RAM | 1TB P...
# 13013  JMO0060-A  Open - Just Mobile Phone Case Skin AluFrame 6 ...
# 2001     PAC0739  1600Mhz RAM expansion kit 16GB SSD Crucial MX2...
# 19049    MTF0008               Mistify Clean Screens Natural 500ml.
# 15176  GTE0066-A  Open - G-Technology G-DRIVE Thunderbolt ev ATC...
# 2723     ZAG0016  ZAGGkeys Keyboard Folio iPad Mini / Mini 3 / R...
# 18843    RYV0008  Qi Wireless Magnetic Ryval PowerBank 8000mAh B...
# 18653    ICA0101  Incase Case Diamond MacBook Pro 13 "and MacBoo...
# 15670  WAC0217-A  Open - Intuos Pro Paper M South Graphics Table...
# 12672  LAC0130-A        Open - 1TB LaCie Rugged USB 3.0 Thunderbolt
# 19246    BNQ0072            EL2870U BenQ Monitor 28 "4K HDR DP HDMI
# 332      NTE0022  NewerTech NuPower battery MacBook Pro 17 "(200...
# 11351    SAM0093                     Samsung S22E450F 215 Monitor "
# 13012    IOT0023  iOttie RapidVOLT Max Dual USB Car Charger Dual...
# 2607     BOS0022                Bose Companion 20 speakers Tabletop
# 18679  WAC0220-A              Open - Wacom Intuos Pro Paper L South
# 15699    SAT0051  Support Satechi Slim MacBook or iMac Aluminum ...
# 18520    TIL0009   Tile Mate Locator Bluetooth White (Pack 4 units)
# 862      SNN0027  Sonnet Echo Express III-D Chassis expansion Th...
# 18123    PRY0011            Prynt iPhone Mobile Printer Pocket Gray
# 14708    QNA0186  QNAP TS-EC880U Xeon E3-1246 R2 Server Nas | 4G...
# 12628  LIF0050-A  (Open) Lifeproof nüüd Waterproof Case iPad Min...
# 14907    TUC0304  Top Tucano Second Skin Case Macbook Pro 15 "(l...
# 2033     TOS0018  Toshiba Canvio Basic Hard Disk 1TB USB 3.0 25 ...
# 15403    REP0377                     Full Screen Repair iPad Mini 3
# 16017    AP20090  Second hand - Apple iPad Mini 2 Wi-Fi 16GB Spa...
# 18770  APP2072-A  Open - Apple MacBook Pro 13 "Core i5 23GHz | 8...
#
#                                                     desc    price  in_stock  \
# 1869   500GB SSD expansion kit + Adapter Mount Pro fo...   215.98       1.0
# 2697   Replacement tray optical bay hard drive for Ma...    39.95       0.0
# 13063  external hard disk 1TB aluminum housing USB co...   106.99       1.0
# 13793  New MacBook Pro 13-inch Core i5 Touch Bar to 3...     2119       0.0
# 12325    Retina MacBook Pro casing 15 inch matte finish.    39.99       0.0
# 2961                              IPhone sports armband.    49.99       0.0
# 7825   IMac desktop computer 27 inch Retina 5K 4GHz C...     4669       0.0
# 2933   sporty and comfortable armband for iPhone 5 / ...    19.95       0.0
# 2025            LED lamp Hue color system works with app    59.95       1.0
# 17416            Refurbished 32GB iPhone rose gold color      419       0.0
# 16905  Expansion box for graphics cards and PCIe card...   422.29       1.0
# 12528  Activity monitor with a personal trainer for i...    79.95       0.0
# 12250  64-piece kit for any repair iPhone iPad Mac an...    32.99       1.0
# 13615  Braided nylon strap with four layers of tissue...       59       0.0
# 18684  External Hard Drive USB 3.0 2TB refurbished wi...   124.99       0.0
# 1218      IPhone 6 Case resistant with transparent back.    19.99       0.0
# 13235          Hard disk WD Red Pro designed for NAS 4TB      279       0.0
# 15940  Protective cover with slip rubber feet for Mac...     29.9       0.0
# 924                         Switch 24 10/100 / 1000Mbps.   144.99       0.0
# 1795   Neoprene Sleeve for MacBook Pro Retina 13 inches.    29.95       0.0
# 2041   Set of 2 LED Smart Bulbs + Wemo Link Control f...    79.99       1.0
# 6354   IMac desktop computer 27 inch 5K Retina i5 3.3...     3889       0.0
# 18807  LifeProof Case submersible in water and resist...    79.99       0.0
# 16885  Apple Mac Pro 12-Core 27GHz 64GB RAM 1TB PCIe SSD     8249       0.0
# 13013                 Aluminum and leather iPhone 6 / 6S    39.99       0.0
# 2001   Mac mini expansion 16GB SSD 1600Mhz RAM 250GB ...   270.96       0.0
# 19049              Spray cleaning screens and keyboards.    14.99       1.0
# 15176  resistant housing with connection Thunderbolt ...   152.72       0.0
# 2723   Backlit keyboard cover with Bluetooth for iPad...    89.99       0.0
# 18843  Ryval portable battery magnetic Qi wireless te...    49.99       0.0
# 18653  Incase Diamond Case with magnetic closure and ...    69.95       1.0
# 15670  Large graphic tablet allows you to design on p...    429.9       0.0
# 12672  Wireless Portable Hard Thunderbolt and USB 3.0...   189.99       0.0
# 19246  BenQ screen 279-inch 4K resolution HDR Display...      349       0.0
# 332                         MacBook Pro 17 inch battery.   145.99       0.0
# 11351             Monitor FHD detachable LED 215 inches.   169.99       0.0
# 13012  Car charger with two USB ports for fast chargi...    19.99       0.0
# 2607   multimedia speakers with rich, natural sound f...   279.99       0.0
# 18679  Reconditioned large graphics tablet lets you d...    599.9       0.0
# 15699  Stand with aluminum finish and practical desig...    49.99       1.0
# 18520  Tile Mate is the locator with Bluetooth for yo...    74.99       1.0
# 862    Thunderbolt external box card PCIe ExpressCard...  1087.79       0.0
# 18123                        Portable Printer for iPhone   159.95       1.0
# 14708  Nas 8-bay rackmount 4GB RAM with 4 USB 3.0 4 E...    314.4       0.0
# 12628  Water resistant protective cover for iPad Mini...   109.99       0.0
# 14907  Protective cover with reinforced zipper and ad...     34.9       0.0
# 2033   25-inch External Hard Drive 1TB USB 3.0 for Ma...    58.99       1.0
# 15403  Repair service including parts and labor for i...   229.99       0.0
# 16017    Reconditioned Apple iPad Mini 2 16GB Space Gray      289       0.0
# 18770  MacBook Pro 13 inch reconditioned i5 23GHz wit...  1505.59       0.0
#
#            type
# 1869       1433
# 2697   12755395
# 13063  11935397
# 13793      2158
# 12325      1298
# 2961       5405
# 7825   5,74E+15
# 2933       5405
# 2025   11905404
# 17416  51601716
# 16905  12995397
# 12528  11905404
# 12250  21485407
# 13615      2449
# 18684  11935397
# 1218   11865403
# 13235  12655397
# 15940      1298
# 924        1334
# 1795   13835403
# 2041   11905404
# 6354   5,74E+15
# 18807  11865403
# 16885  21632158
# 13013  11865403
# 2001       1433
# 19049  12085400
# 15176      1298
# 2723   12575403
# 18843      1515
# 18653  13835403
# 15670      1405
# 12672      1298
# 19246      1296
# 332       10142
# 11351      1296
# 13012  13615399
# 2607       5398
# 18679      1405
# 15699      8696
# 18520  11905404
# 862    12995397
# 18123  11905404
# 14708  12175397
# 12628      1298
# 14907  13835403
# 2033   11935397
# 15403  1,44E+11
# 16017  12031714
# 18770  1,02E+12
